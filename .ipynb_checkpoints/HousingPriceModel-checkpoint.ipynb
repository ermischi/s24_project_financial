# %% [markdown]
# # Project Work
# # CMSE 202 final project
# ## Group 0

# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Jose, Narayana, Max, Insaan

# %% [markdown]
# ## Imports and reading in the data
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn import metrics

# %%
#Reading data in
housing = pd.read_csv("realtor-data.zip.csv", delimiter = ',')
housing = housing.dropna()
housing

# %% [markdown]
# ## 1. Masking Data based on State
#
# ---

# %%
#Splitting houses sold and houses still for sale
sold_houses = housing[housing["status"] == "sold"]
for_sale_houses = housing[housing["status"] == "for_sale"]

# %%
#Masking based on state.
MI = housing[housing["state"] == "Michigan"]

# %% [markdown]
# ## 2. First Linear Regression model with entire dataset
#
# ---

# %%
# Linear Regression model made with entire dataset
x = housing["price"]
y = housing["house_size"]
X = sm.add_constant(x)

model = sm.OLS(y, X)
results = model.fit()
print("Regression Results for Houses Dataset")
print(results.summary())
# Out:
# Regression Results for Houses Dataset
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             house_size   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                 3.962e+04
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):               0.00
# Time:                        20:44:39   Log-Likelihood:            -1.0119e+07
# No. Observations:             1084909   AIC:                         2.024e+07
# Df Residuals:                 1084907   BIC:                         2.024e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1824.9439      2.896    630.068      0.000    1819.267    1830.621
# price          0.0004   2.21e-06    199.049      0.000       0.000       0.000
# ===============================================================================
# Omnibus:                  5831311.965   Durbin-Watson:                    1.801
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   700288371589089.000
# Skew:                         279.669   Prob(JB):                          0.00
# Kurtosis:                  124466.794   Cond. No.                      1.46e+06
# ===============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 3a. Linear Regression within state of Michigan.
#
# ---

# %%
# This code runs a linear regression for all houses in the state of michigan (according to the data set)
x = MI["price"]
y = MI["house_size"]
X = sm.add_constant(x)

model = sm.OLS(y, X)
results = model.fit()
print("Regression Results for Michigan Houses")
print(results.summary())
# Out:
# Regression Results for Michigan Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             house_size   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                 1.155e+04
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:54:49   Log-Likelihood:            -1.1990e+05
# No. Observations:               14806   AIC:                         2.398e+05
# Df Residuals:                   14804   BIC:                         2.398e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1246.4705      8.362    149.062      0.000    1230.080    1262.861
# price          0.0019   1.81e-05    107.481      0.000       0.002       0.002
# ==============================================================================
# Omnibus:                    10426.184   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7593906.484
# Skew:                           2.059   Prob(JB):                         0.00
# Kurtosis:                     113.872   Cond. No.                     5.91e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.91e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### 3b. Masking even more houses with East Lansing specifically.
#
# ---

# %%
# Splitting Michigan houses into just East Lansing homes
EL = MI[MI["city"] == "East Lansing"]

# Splitting East Lansing Homes by houses for sale and old
EL_sale = EL[EL["status"] == "for_sale"]
print(f"There are {len(EL)} homes in East Lansing within this dataset.")
# Out:
# There are 150 homes in East Lansing within this dataset.

# %% [markdown]
# ### 3c. Plot of Price vs House Size, with different number of beds sorted by color.
#
# ---

# %%
#T his code separates the east lansing houses by bed count, stores them into different variables,
# then plots them with different colors based off their number of beds

EL_1_bed = EL[EL["bed"] == 1]
EL_2_bed = EL[EL["bed"] == 2]
EL_3_bed = EL[EL["bed"] == 3]
EL_4_bed = EL[EL["bed"] == 4]
EL_5_bed = EL[EL["bed"] == 5]
EL_6_bed = EL[EL["bed"] >= 6]

EL_4000 = EL.loc[(EL["house_size"] > 3000) & (EL["house_size"] <= 4000)]
EL_5000 = EL.loc[(EL["house_size"] > 4000) & (EL["house_size"] <= 5000)]


plt.figure(figsize=(11, 5))
plt.scatter(EL_1_bed["house_size"], EL_1_bed["price"], c='#77F729', alpha=0.5, label = "1 Bed")
plt.scatter(EL_2_bed["house_size"], EL_2_bed["price"], c='#4D9D1D', alpha=0.5, label = "2 Beds")
plt.scatter(EL_3_bed["house_size"], EL_3_bed["price"], c='#309DF2', alpha=0.5, label = "3 Beds")
plt.scatter(EL_4_bed["house_size"], EL_4_bed["price"], c='#C51A17', alpha=0.5, label = "4 Beds")
plt.scatter(EL_5_bed ["house_size"], EL_5_bed["price"], c='#A25E09', alpha=0.5, label = "5 Beds")
plt.scatter(EL_6_bed["house_size"], EL_6_bed["price"], c='#57106E', alpha=0.5, label = "6+ Beds")
plt.title('Price vs. Area Based (Including bed count)')
plt.xlabel('Area (Square feet)')
plt.ylabel('Price (US dollars)')
plt.grid(True)
plt.legend()
plt.show()

# %%
print("Same plot as above, just easier to read 0 - 4000")
plt.figure(figsize=(11, 5))
plt.scatter(EL_1_bed["house_size"], EL_1_bed["price"], c='#77F729', alpha=0.5, label = "1 Bed")
plt.scatter(EL_2_bed["house_size"], EL_2_bed["price"], c='#4D9D1D', alpha=0.5, label = "2 Beds")
plt.scatter(EL_3_bed["house_size"], EL_3_bed["price"], c='#309DF2', alpha=0.5, label = "3 Beds")
plt.scatter(EL_4_bed["house_size"], EL_4_bed["price"], c='#C51A17', alpha=0.5, label = "4 Beds")
plt.title('Price vs. Area Based (Including bed count)')
plt.xlabel('Area (Square feet)')
plt.ylabel('Price (US dollars)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Same plot as above, just easier to read 0 - 4000

# %% [markdown]
# ### 3d. Multiple Regression of East Lansing houses currently being sold
#
# ---

# %%
#This is the regression model for JUST the East Lansing houses for sale
X = EL_sale.drop(["brokered_by", "status", "price", "street", "city", "state", "zip_code", "city", "prev_sold_date"], axis = 1)
Y = EL_sale["price"]
    
X = sm.add_constant(X)

multi_model = sm.OLS(Y, X).fit()
print("Regression Results for East Lansing Houses")
print(multi_model.summary())
# Out:
# Regression Results for East Lansing Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     235.6
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           1.06e-27
# Time:                        22:53:31   Log-Likelihood:                -584.59
# No. Observations:                  46   AIC:                             1179.
# Df Residuals:                      41   BIC:                             1188.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.558e+04   5.09e+04      1.092      0.281   -4.72e+04    1.58e+05
# bed        -1.364e+04   1.86e+04     -0.732      0.468   -5.13e+04     2.4e+04
# bath        1.283e+04   3.08e+04      0.416      0.679   -4.94e+04    7.51e+04
# acre_lot    1136.1955     83.122     13.669      0.000     968.328    1304.063
# house_size   128.5727     24.494      5.249      0.000      79.106     178.040
# ==============================================================================
# Omnibus:                        5.783   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                7.573
# Skew:                          -0.186   Prob(JB):                       0.0227
# Kurtosis:                       4.953   Cond. No.                     1.31e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### 3d. Diagnostics plots features within Regression Model
#
# ---

# %%
#This code plots each of the unique features within the regression model
print("Making diagnostics plots for each of the main features within the regression model")
for feature in ['bed', 'bath', 'acre_lot', 'house_size']:
    fig, ax = plt.subplots(figsize=(12, 8))
    sm.graphics.plot_regress_exog(multi_model, feature, fig=fig)
    plt.title(f'Regression Diagnostics for {feature}.')
    plt.show()
# Out:
# Making diagnostics plots for each of the main features within the regression model

# %% [markdown]
# ## 4. Regression results for top 20 biggest universities in US, followed by 20 cities without major colleges
#
# ---

# %%
# Function used to do multiple regression through all cities being tested
def regress(data, state, city):
    '''
    This function was created for ease of programming when running the multiple regression models
    this takes in the state, city, and dataset we needs to regress, it masks based on the state, and city wanted
    the drops the unnecessary features, and runs a multiple regression model for the specified parameters.
    '''
    
    state_masked = data[data["state"] == state]
    if len(state_masked) == 0:
        pass
    else:      
        city_masked = state_masked[state_masked["city"] == city]
        if len(city_masked) == 0:
            pass
        else:
            X = city_masked.drop(["brokered_by", "status", "price", "street", "city", "state", "zip_code", "city", "prev_sold_date"], axis = 1)
            Y = city_masked["price"]
                
            X = sm.add_constant(X)
            
            multi_model = sm.OLS(Y, X).fit()
            
            print(f"Regression Results for {city} Houses")
            print(multi_model.summary())

# %%
# Function used get total list of cities based on state specified
def print_states(state):
    '''
    This function is used to avoid copying and pasting for loops for every state within our specified parameters
    It masks the whole dataset into state based off state, then displays each city within the specified state
    and prints the list of states
    '''
    
    state_masked = housing[housing["state"] == state]
    unique_city = []
    for i in state_masked["city"]:
        if i not in unique_city:
            unique_city.append(i)

    print(unique_city)

# %%
# This dictionary contains the states of the 20 biggest colleges in the U.S
# Accessed from https://blog.collegevine.com/biggest-colleges-in-the-us
states_w_cities = {"Michigan": ["East Lansing", "Grosse Pointe Woods"], 
          "Arizona": ["Tucson", "Ash Fork"], 
          "Florida": ["Tallahassee", "Gainesville", "Orlando", "Key West"], 
          "Texas": ["Austin", "College Station", "Frisco"], 
          "Pennsylvania": ["University Park", "Cranberry Township"], 
          "Indiana": ["Bloomington", "West Lafayette", "Morgantown"], 
          "Minnesota": ["Minneapolis", "Pine City" ], 
          "Ohio": ["Columbus", "Fostoria"], 
          "New Jersey": ["New Brunswick", "Stillwater"], 
          "Illinois": ["Champaign", "Elgin" ],
          "California": ["Los Angeles", "Northridge", "Oak Park", "San Marcos"],
          "Alabama": ["Tusca Loosa", "Fairhope"],
          "Wisconsin": ["Madison", "Pleasant Prairie"],
          "Iowa": ["Ames", "Council Bluffs"] }

# %% [markdown]
# The code below was used to search through each state being tested and show the cities to be compared to. There are thousands of cities within all of these states, so the code is commented out to save scrolling time. Obviously because of the random drafting of comparison cities, these results will be interesting to see, but not have a great basis on why values are so different, as we are not looking at quantity of houses in each city.

# %%
#for i in states_w_cities.keys():
#    print(i)
#    print_states(i)

# %% [markdown]
# The code below runs the regression for over 20 different cities, if you take a look at the dictionary above, not all states have the same number of cities, that is because according to the website mentioned above, some states had multiple big schools in them, for all states however the last city in each state is the state being compared to, that is, the state that did NOT have a major university in it.
#
# If you look above the first regression, you'll see Text that shows the current state, followed by the cities within the state. Each regression displays the current city in the iteration, it can be very confusing to tell which city you're at, and thus a summary of the findings can be found under the models.

# %%
#Code that iterates through each state, then city, and uses above regression function to find results
for state, cities in states_w_cities.items():
    print("")
    print("")
    print(f"{state}'s cities within the dictionary are: {cities}")
    for city in cities:
        print("")
        print("")
        regress(housing, state, city)
# Out:
# Michigan's cities within the dictionary are: ['East Lansing', 'Grosse Pointe Woods']
#
#
# Regression Results for East Lansing Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                
29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Florida's cities within the dictionary are: ['Tallahassee', 'Gainesville', 'Orlando', 'Key West']
#
#
# Regression Results for Tallahassee Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     844.5
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):          1.81e-254
# Time:                        22:18:01   Log-Likelihood:                -8449.5
# No. Observations:                 649   AIC:                         1.691e+04
# Df Residuals:                     644   BIC:                         1.693e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8.312e+04   1.71e+04     -4.856      0.000   -1.17e+05   -4.95e+04
# bed        -4.129e+04   6934.901     -5.953      0.000   -5.49e+04   -2.77e+04
# bath        4.555e+04   7066.142      6.446      0.000    3.17e+04    5.94e+04
# acre_lot    6094.4224    579.498     10.517      0.000    4956.489    7232.356
# house_size   236.4272      8.038     29.415      0.000     220.644     252.211
# ==============================================================================
# Omnibus:                      127.666   Durbin-Watson:                   1.694
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              983.775
# Skew:                           0.639   Prob(JB):                    2.38e-214
# Kurtosis:                       8.895   Cond. No.                     8.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Gainesville Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     1211.
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:18:01   Log-Likelihood:                -13469.
# No. Observations:                1036   AIC:                         2.695e+04
# Df Residuals:                    1031   BIC:                         2.697e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.651e+04   1.14e+04     -3.204      0.001   -5.89e+04   -1.41e+04
# bed        -3.721e+04   4732.483     -7.862      0.000   -4.65e+04   -2.79e+04
# bath        1.952e+04   5576.688      3.501      0.000    8578.855    3.05e+04
# acre_lot    4496.8707   1073.371      4.189      0.000    2390.630    6603.112
# house_size   247.1653      6.338     38.998      0.000     234.729     259.602
# ==============================================================================
# Omnibus:                      202.721   Durbin-Watson:                   1.714
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4326.113
# Skew:                           0.245   Prob(JB):                         0.00
# Kurtosis:                      12.999   Cond. No.                     7.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Orlando Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.534
# Method:                 Least Squares   F-statistic:                     1640.
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:18:01   Log-Likelihood:                -81120.
# No. Observations:                5733   AIC:                         1.622e+05
# Df Residuals:                    5728   BIC:                         1.623e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.036e+05   1.53e+04     -6.758      0.000   -1.34e+05   -7.35e+04
# bed        -1.166e+05   6576.204    -17.728      0.000   -1.29e+05   -1.04e+05
# bath        4.353e+04   8120.843      5.361      0.000    2.76e+04    5.95e+04
# acre_lot       5.9691     28.497      0.209      0.834     -49.895      61.833
# house_size   440.2778      9.718     45.305      0.000     421.227     459.329
# ==============================================================================
# Omnibus:                    15756.916   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        858783434.528
# Skew:                          34.072   Prob(JB):                         0.00
# Kurtosis:                    1897.854   Cond. No.                     7.25e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Key West Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.595
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                     74.10
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           1.48e-38
# Time:                        22:18:01   Log-Likelihood:                -3127.1
# No. Observations:                 207   AIC:                             6264.
# Df Residuals:                     202   BIC:                             6281.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.263e+05   1.61e+05     -3.271      0.001   -8.44e+05   -2.09e+05
# bed        -3.254e+04   7.51e+04     -0.433      0.665   -1.81e+05    1.16e+05
# bath          2.9e+05   8.65e+04      3.353      0.001    1.19e+05    4.61e+05
# acre_lot   -7634.3785   6.34e+04     -0.120      0.904   -1.33e+05    1.17e+05
# house_size   985.7968    153.673      6.415      0.000     682.788    1288.806
# ==============================================================================
# Omnibus:                       64.362   Durbin-Watson:                   1.690
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              213.555
# Skew:                           1.251   Prob(JB):                     4.24e-47
# Kurtosis:                       7.302   Cond. No.                     4.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Texas's cities within the dictionary are: ['Austin', 'College Station', 'Frisco']
#
#
# Regression Results for Austin Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0
55e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Pine City Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.352
# Method:                 Least Squares   F-statistic:                     7.117
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           0.000190
# Time:                        22:18:02   Log-Likelihood:                -597.17
# No. Observations:                  46   AIC:                             1204.
# Df Residuals:                      41   BIC:                             1213.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.167e+04   7.63e+04      0.284      0.778   -1.32e+05    1.76e+05
# bed         3.333e+04   2.94e+04      1.135      0.263    -2.6e+04    9.26e+04
# bath       -1.382e+04   3.11e+04     -0.444      0.659   -7.67e+04     4.9e+04
# acre_lot    -881.8032   4370.355     -0.202      0.841   -9707.914    7944.308
# house_size   112.1710     38.552      2.910      0.006      34.313     190.029
# ==============================================================================
# Omnibus:                       26.673   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.833
# Skew:                           1.729   Prob(JB):                     4.10e-11
# Kurtosis:                       6.605   Cond. No.                     1.00e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Ohio's cities within the dictionary are: ['Columbus', 'Fostoria']
#
#
# Regression Results for Columbus Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     376.1
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):          1.25e-195
# Time:                        22:18:02   Log-Likelihood:                -12929.
# No. Observations:                 977   AIC:                         2.587e+04
# Df Residuals:                     972   BIC:                         2.589e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.059e+04   1.65e+04      1.858      0.063   -1710.307    6.29e+04
# bed        -4.625e+04   6345.420     -7.289      0.000   -5.87e+04   -3.38e+04
# bath        5.049e+04   6588.303      7.664      0.000    3.76e+04    6.34e+04
# acre_lot    -188.4600    105.190     -1.792      0.074    -394.886      17.966
# house_size   189.8972      8.474     22.409      0.000     173.267     206.527
# ==============================================================================
# Omnibus:                      322.955   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3014.767
# Skew:                           1.236   Prob(JB):                         0.00
# Kurtosis:                      11.243   Cond. No.                     7.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Fostoria Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     66.40
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           2.25e-16
# Time:                        22:18:02   Log-Likelihood:                -522.60
# No. Observations:                  42   AIC:                             1055.
# Df Residuals:                      37   BIC:                             1064.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -3.24e+04   4.78e+04     -0.678      0.502   -1.29e+05    6.45e+04
# bed        -7310.2668   1.55e+04     -0.473      0.639   -3.86e+04     2.4e+04
# bath        5.938e+04   1.63e+04      3.653      0.001    2.64e+04    9.23e+04
# acre_lot    7838.9555   1226.704      6.390      0.000    5353.417    1.03e+04
# house_size    55.3225     20.052      2.759      0.009      14.692      95.953
# ==============================================================================
# Omnibus:                        5.853   Durbin-Watson:                   2.516
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                7.234
# Skew:                           0.239   Prob(JB):                       0.0269
# Kurtosis:                       4.976   Cond. No.                     1.03e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# New Jersey's cities within the dictionary are: ['New Brunswick', 'Stillwater']
#
#
# Regression Results for New Brunswick Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     14.94
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           5.75e-09
# Time:                        22:18:02   Log-Likelihood:                -1008.2
# No. Observations:                  78   AIC:                             2026.
# Df Residuals:                      73   BIC:                             2038.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.902e+04   3.83e+04      2.066      0.042    2774.726    1.55e+05
# bed         4.937e+04   1.54e+04      3.198      0.002    1.86e+04    8.01e+04
# bath        4.383e+04   2.21e+04      1.983      0.051    -216.205    8.79e+04
# acre_lot    5.114e+04   6.88e+04      0.743      0.460    -8.6e+04    1.88e+05
# house_size    26.5935     44.198      0.602      0.549     -61.493     114.680
# ==============================================================================
# Omnibus:                       20.574   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.922
# Skew:                           1.296   Prob(JB):                     2.35e-06
# Kurtosis:                       4.120   Cond. No.                     8.64e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.64e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Stillwater Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     15.64
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):             0.0104
# Time:                        22:18:02   Log-Likelihood:                -106.58
# No. Observations:                   9   AIC:                             223.2
# Df Residuals:                       4   BIC:                             224.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.097e+05   9.56e+04     -1.148      0.315   -3.75e+05    1.56e+05
# bed         7877.7916   2.87e+04      0.275      0.797   -7.18e+04    8.75e+04
# bath       -5.949e+04   7.45e+04     -0.798      0.469   -2.66e+05    1.47e+05
# acre_lot   -1.261e+04   1.74e+04     -0.725      0.509   -6.09e+04    3.57e+04
# house_size   296.4520    141.250      2.099      0.104     -95.722     688.625
# ==============================================================================
# Omnibus:                        0.727   Durbin-Watson:                   2.402
# ...
#
#
# Regression Results for Oak Park Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     154.7
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           1.45e-29
# Time:                        22:18:02   Log-Likelihood:                -816.14
# No. Observations:                  61   AIC:                             1642.
# Df Residuals:                      56   BIC:                             1653.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.337e+04   7.54e+04      0.575      0.567   -1.08e+05    1.94e+05
# bed        -6.817e+04   3.63e+04     -1.879      0.065   -1.41e+05    4503.641
# bath        3.241e+04   5.08e+04      0.638      0.526   -6.94e+04    1.34e+05
# acre_lot    2.748e+06   4.85e+05      5.667      0.000    1.78e+06    3.72e+06
# house_size   421.5932     84.359      4.998      0.000     252.601     590.585
# ==============================================================================
# Omnibus:                       14.398   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               24.605
# Skew:                          -0.753   Prob(JB):                     4.54e-06
# Kurtosis:                       5.722   Cond. No.                     5.32e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.32e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for San Marcos Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     218.9
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):          1.64e-101
# Time:                        22:18:02   Log-Likelihood:                -5965.3
# No. Observations:                 427   AIC:                         1.194e+04
# Df Residuals:                     422   BIC:                         1.196e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.557e+05   5.05e+04     -3.085      0.002   -2.55e+05   -5.65e+04
# bed         2.915e+04   2.09e+04      1.397      0.163   -1.19e+04    7.02e+04
# bath        1.368e+04   2.62e+04      0.522      0.602   -3.79e+04    6.52e+04
# acre_lot       0.7287      2.019      0.361      0.718      -3.239       4.697
# house_size   479.9327     31.635     15.171      0.000     417.752     542.114
# ==============================================================================
# Omnibus:                      181.818   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1570.658
# Skew:                           1.592   Prob(JB):                         0.00
# Kurtosis:                      11.840   Cond. No.                     2.63e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.63e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Alabama's cities within the dictionary are: ['Tusca Loosa', 'Fairhope']
#
#
#
#
# Regression Results for Fairhope Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     9.312
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           9.96e-06
# Time:                        22:18:03   Log-Likelihood:                -835.62
# No. Observations:                  56   AIC:                             1681.
# Df Residuals:                      51   BIC:                             1691.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.622e+05   4.47e+05      0.586      0.561   -6.36e+05    1.16e+06
# bed        -3.264e+05   1.59e+05     -2.048      0.046   -6.46e+05   -6433.273
# bath        2.675e+05   1.44e+05      1.853      0.070   -2.23e+04    5.57e+05
# acre_lot    1.274e+05   8.87e+04      1.437      0.157   -5.07e+04    3.06e+05
# house_size   294.8551    121.604      2.425      0.019      50.725     538.985
# ==============================================================================
# Omnibus:                       36.039   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.683
# Skew:                           1.989   Prob(JB):                     4.09e-19
# Kurtosis:                       7.525   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Wisconsin's cities within the dictionary are: ['Madison', 'Pleasant Prairie']
#
#
# Regression Results for Madison Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.560
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     239.7
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):          1.27e-132
# Time:                        22:18:03   Log-Likelihood:                -9951.6
# No. Observations:                 757   AIC:                         1.991e+04
# Df Residuals:                     752   BIC:                         1.994e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.272e+05   1.44e+04      8.845      0.000     9.9e+04    1.55e+05
# bed         -2.35e+04   5452.834     -4.309      0.000   -3.42e+04   -1.28e+04
# bath       -2.638e+04   7000.142     -3.769      0.000   -4.01e+04   -1.26e+04
# acre_lot    1.021e+05   1.29e+04      7.910      0.000    7.68e+04    1.27e+05
# house_size   200.5650      9.817     20.430      0.000     181.292     219.838
# ==============================================================================
# Omnibus:                      498.030   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11096.116
# Skew:                           2.591   Prob(JB):                         0.00
# Kurtosis:                      21.026   Cond. No.                     7.00e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Pleasant Prairie Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     15.51
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           1.17e-05
# Time:                        22:18:03   Log-Likelihood:                -302.85
# No. Observations:                  23   AIC:                             615.7
# Df Residuals:                      18   BIC:                             621.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.957e+04   1.28e+05      0.700      0.493   -1.79e+05    3.58e+05
# bed        -4.796e+04   4.95e+04     -0.969      0.346   -1.52e+05    5.61e+04
# bath       -2.767e+04   5.46e+04     -0.507      0.619   -1.42e+05    8.71e+04
# acre_lot    1.112e+04   8.25e+04      0.135      0.894   -1.62e+05    1.84e+05
# house_size   244.3159     51.616      4.733      0.000     135.875     352.756
# ==============================================================================
# Omnibus:                        2.237   Durbin-Watson:                   1.748
# Prob(Omnibus):                  0.327   Jarque-Bera (JB):                1.110
# Skew:                           0.519   Prob(JB):                        0.574
# Kurtosis:                       3.286   Cond. No.                     1.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Iowa's cities within the dictionary are: ['Ames', 'Council Bluffs']
#
#
# Regression Results for Ames Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     147.8
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           5.23e-70
# Time:                        22:18:03   Log-Likelihood:                -3970.5
# No. Observations:                 309   AIC:                             7951.
# Df Residuals:                     304   BIC:                             7970.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8.062e+04   1.95e+04     -4.141      0.000   -1.19e+05   -4.23e+04
# bed         2.865e+04   7031.325      4.075      0.000    1.48e+04    4.25e+04
# bath        4.439e+04   7819.045      5.677      0.000     2.9e+04    5.98e+04
# acre_lot    5.081e+04   8129.089      6.250      0.000    3.48e+04    6.68e+04
# house_size   100.1912     14.375      6.970      0.000      71.904     128.478
# ==============================================================================
# Omnibus:                       39.505   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.671
# Skew:                           0.484   Prob(JB):                     7.73e-31
# Kurtosis:                       6.136   Cond. No.                     6.11e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Regression Results for Council Bluffs Houses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     97.22
# Date:                Sat, 20 Apr 2024   Prob (F-statistic):           2.11e-34
# Time:                        22:18:03   Log-Likelihood:                -1354.0
# No. Observations:                 110   AIC:                             2718.
# Df Residuals:                     105   BIC:                             2731.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.109e+04   2.01e+04      0.551      0.583   -2.88e+04     5.1e+04
# bed        -2582.8387   6840.885     -0.378      0.707   -1.61e+04     1.1e+04
# bath        4.725e+04   8405.563      5.621      0.000    3.06e+04    6.39e+04
# acre_lot    4.307e+04   5934.619      7.257      0.000    3.13e+04    5.48e+04
# house_size    60.8080     11.244      5.408      0.000      38.512      83.104
# ==============================================================================
# Omnibus:                       12.616   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               38.573
# Skew:                          -0.104   Prob(JB):                     4.21e-09
# Kurtosis:                       5.893   Cond. No.                     7.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 5. Summary of Results
#
# ---

# %% [markdown]
# The adjusted r-squared values were the values compared in this evaluation, some cities in this data-set did not have all of the features used to compare, which is a shame, as some of the cities are in the top 20 biggest universities according to our source, so the option of changing the city wasn't exactly applicable, so University Park in Pennsylvania, and Tusca Loosa in Alabama weren't able to determine r-squared values.
#
# In terms of the states that were successful, the college cities in Michigan, Arizona, Minnesota, and Illinois all have higher adjusted R-squared values than their counterparts without major universities. While the Big University cities in Ohio, New Jersey, Iowa, and Wisconsin all have lower R-squared values than their counterparts, The states that had multiple universities in them, like Florida, Texas, Indiana, and California have mixed results, with some being above the city without a major university, and some below.
#
# What this means is that the features used to make these models: Based on these few cities, would lean more towards the non-major university cities fitting the model better than the big university cities. But in some cases its the opposite.
#
# It's also important to consider the fact that we don't have the financial status of these cities in general, we are given the prices of the houses, but that doesn't show the political side of things, and the overall status of each city, so there are some limitations to these models to acknowledge.

# %%
#Code prints each city and its respective r squared values 
adjust_rs = [ 0.914, 0.847, 0.713, 0.583, 0.839, 0.824, 0.534, 0.587, 0.708, 0.753, 0.734, "nan", 0.807, 0.452, 0.870, 0.514, 
             0.582, 0.352, 0.606, 0.865, 0.420, 0.880, 0.800, 0.769, 0.629, 0.889, 0.911, 0.672, "nan", 0.377, 0.558, 0.725, 0.656, 0.779]

count = 0
for state, cities in states_w_cities.items():
    print("")
    print(state)
    print("-----------------------------------------")
    for city in cities:
        print(f"{city}'s r-squared is: {adjust_rs[count]}")
        count += 1
# Out:
# Michigan
# -----------------------------------------
# East Lansing's r-squared is: 0.914
# Grosse Pointe Woods's r-squared is: 0.847
#
# Arizona
# -----------------------------------------
# Tucson's r-squared is: 0.713
# Ash Fork's r-squared is: 0.583
#
# Florida
# -----------------------------------------
# Tallahassee's r-squared is: 0.839
# Gainesville's r-squared is: 0.824
# Orlando's r-squared is: 0.534
# Key West's r-squared is: 0.587
#
# Texas
# -----------------------------------------
# Austin's r-squared is: 0.708
# College Station's r-squared is: 0.753
# Frisco's r-squared is: 0.734
#
# Pennsylvania
# -----------------------------------------
# University Park's r-squared is: nan
# Cranberry Township's r-squared is: 0.807
#
# Indiana
# -----------------------------------------
# Bloomington's r-squared is: 0.452
# West Lafayette's r-squared is: 0.87
# Morgantown's r-squared is: 0.514
#
# Minnesota
# -----------------------------------------
# Minneapolis's r-squared is: 0.582
# Pine City's r-squared is: 0.352
#
# Ohio
# -----------------------------------------
# Columbus's r-squared is: 0.606
# Fostoria's r-squared is: 0.865
#
# New Jersey
# -----------------------------------------
# New Brunswick's r-squared is: 0.42
# Stillwater's r-squared is: 0.88
#
# Illinois
# -----------------------------------------
# Champaign's r-squared is: 0.8
# Elgin's r-squared is: 0.769
#
# California
# -----------------------------------------
# Los Angeles's r-squared is: 0.629
# Northridge's r-squared is: 0.889
# Oak Park's r-squared is: 0.911
# San Marcos's r-squared is: 0.672
#
# Alabama
# -----------------------------------------
# Tusca Loosa's r-squared is: nan
# Fairhope's r-squared is: 0.377
#
# Wisconsin
# -----------------------------------------
# Madison's r-squared is: 0.558
# Pleasant Prairie's r-squared is: 0.725
#
# Iowa
# -----------------------------------------
# Ames's r-squared is: 0.656
# Council Bluffs's r-squared is: 0.779
