# %% [markdown]
# # Project Work
# # CMSE 202 final project
# ## Group 0

# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Jose, Narayana, Max, Insaan

# %% [markdown]
# ## Imports and reading in the data
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing = pd.read_csv("Housing.csv", delimiter = ',')
house_prices = housing["price"]
house_area = housing["area"]

# %% [markdown]
# ## 1. Plot of Housing Prices vs area of houses
#
# ---

# %%
plt.figure(figsize=(10, 6))
plt.scatter(house_area, house_prices, color='blue', alpha=0.5)
plt.title('Price vs. Area')
plt.xlabel('Area (Square feet)')
plt.ylabel('Price (US dollars)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Correlation of all features withi
#
# ---

# %%
plt.figure(figsize=(4,4))
sns.pairplot(housing, diag_kind="hist", height=2)
plt.show()

# %% [markdown]
# ## 3.
#
# ---
